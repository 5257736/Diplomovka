# %% [markdown]
# **Autori:** Andrej Gajdoš, Dagmara Lopatková  <br>
# *[Ústav matematických vied](https://www.upjs.sk/prirodovedecka-fakulta/ustav/umv/), [Prírodovedecká fakulta](https://www.upjs.sk/prirodovedecka-fakulta/), Univerzita Pavla Jozefa Šafárika v Košiciach,* <br>
# email: [andrej.gajdos@upjs.sk](mailto:andrej.gajdos@upjs.sk)
#
# ***
#
# **<font size=6 color=blue> MTIa: Téma 6 - Analytická geometria 1 </font>**

# %% [markdown]
# ---
#
# #### 1. Čo vytvoria spolu všetky vektory v tvare $p\boldsymbol{u}$, kde $p\in\mathbb{R}$ sa mení a $\boldsymbol{u}\in\mathbb{R}^2$ je pevne zvolený nulový vektor v rovine (2D) ?
#
# <font color=blue> a) Jeden bod </font>
# b) Úsečku
# c) Priamku
# d) Celú rovinu
#
# <ins> Vysvetlenie: </ins>
# V tomto prípade, keďže $\boldsymbol{u}$ je nulový vektor, potom všetky vektory v tvare $p\boldsymbol{u}$ budú tiež nulové vektory. To znamená, že všetky tieto vektory budú bodmi v rovine, ale všetky budú ležať v jednom bode.
#
# Takže v tomto prípade, všetky vektory v tvare $p\boldsymbol{u}$, kde $\boldsymbol{u}=0$, tvoria jednoducho bod v rovine, ktorý je počiatkom súradnicového systému.
#
# APPLET: https://www.geogebra.org/m/mqb8jayt

# %% [markdown]
# ---
#
# #### 2.  Čo vytvoria spolu všetky vektory v tvare $p\boldsymbol{u}$, kde $p\in\mathbb{R}$ sa mení a $\boldsymbol{u}\in\mathbb{R}^2$ je pevne zvolený nenulový vektor v rovine (2D) ?
#
# a) Jeden bod
# b) Úsečku
# <font color=blue> c) Priamku </font>
# d) Celú rovinu
#
# <ins> Vysvetlenie: </ins>
# Ak máme pevne zvolený nenulový vektor $\boldsymbol{u}$ v rovine, potom všetky násobky tohto vektora $p\boldsymbol{u}$, kde $p$ môže nadobúdať ľubovoľné reálne hodnoty, budú ležať na priamke, ktorá prechádza počiatkom smerom vektora $\boldsymbol{u}$.
#
# Týmto spôsobom môžeme tvoriť priamky v 2-rozmernom priestore. Ak $p$ je kladné, bod bude na tej istej strane počiatočného bodu ako vektor $\boldsymbol{u}$. Ak je $p$ záporné, bod bude na opačnej strane.
#
# Takže všetky vektory v tvare $p\boldsymbol{u}$ sú vlastne násobkami vektora  $\boldsymbol{u}$ a tvoria priamku v rovine, ktorá prechádza počiatkom a má smer daný vektorom  $\boldsymbol{u}$.
#
# APPLET: https://www.geogebra.org/m/mqb8jayt

# %% [markdown]
# ---
#
# #### 3. Čo vytvoria spolu všetky vektory v tvare $p\boldsymbol{u}+q\boldsymbol{v}$, kde $p,q\in\mathbb{R}$ sa menia a $\boldsymbol{u},\boldsymbol{v}\in\mathbb{R}^2$ sú pevne zvolené nenulové vektory v rovine (2D) ?
#
# a) Jeden bod
# b) Úsečku
# <font color=blue> c) Priamku </font>
# <font color=blue> d) Celú rovinu </font>
#
# <ins> Vysvetlenie: </ins>
# Ak máme dva nenulové lineárne NEZÁVISLÉ vektory $\boldsymbol{u}$ a $\boldsymbol{v}$ v rovine, každý vektor v tvare $p\boldsymbol{u}+q\boldsymbol{v}$ je lineárna kombinácia týchto dvoch vektorov, kde $p$ a $q$ sú reálne čísla. Keďže môžeme zvoliť akékoľvek hodnoty $p$ a $q$, môžeme získať všetky možné lineárne kombinácie týchto vektorov, čo vytvorí rovinu.
#
# Takže všetky vektory v tvare $p\boldsymbol{u}+q\boldsymbol{v}$ vytvoria rovinu v 2-rozmernom priestore, ktorá je určená vektormi $\boldsymbol{u}$ a $\boldsymbol{v}$.
#
# Ale máme možnosť, že vektory budú lineárne ZÁVISLÉ a v takom prípade vytvoria len priamku v 2D.
#
# APPLET:
# https://www.geogebra.org/m/w2phrct9

# %% [markdown]
# ---
#
# #### 4. Je sčítanie (dvoch) vektorov komutatívne? T. j. platí pre vektory $\boldsymbol{u},\boldsymbol{v}\in\mathbb{R}^2$, že $\boldsymbol{u}+\boldsymbol{v}=\boldsymbol{v}+\boldsymbol{u}$ ?
#
# <font color=blue> a) Áno   </font>
# b) Nie
#
# <ins> Vysvetlenie: </ins>
# Vyplýva to z **definície sčítania vektorov**.
#
# Keďže sčítanie vektorov prebieha po zložkách, t.j., sčítame zložku $x$ s $x$, a zložku $y$ s $y$, poradie, v ktorom sčítame vektory, nemá vplyv na výsledok. To znamená, že výsledný vektor je rovnaký bez ohľadu na to, či najprv sčítame $\mathbf{u}$ s $\mathbf{v}$ alebo $\mathbf{v}$ s $\mathbf{u}$.
#
# Ilustračný príklad:
# $\mathbf{u} = (1, 2)$
# $\mathbf{v} = (3, 4)$
# Výpočet:
# $w_1 = \mathbf{u} + \mathbf{v}$
# $w_1 = \mathbf{u} + \mathbf{v} = (1, 2) + (3, 4) = (1 + 3, 2 + 4) = (4, 6)$
#
#
# $w_2 = \mathbf{v} + \mathbf{u}$
# $w_2 = \mathbf{v} + \mathbf{u} = (3, 4) + (1, 2) = (3 + 1, 4 + 2) = (4, 6)$
#
#
# $w_1 = w_2$
#
# APPLET: https://www.geogebra.org/m/khsbmkgw

# %% [markdown]
# ---
#
# #### 5.  Príkladom lineárnej kombinácie vektorov $\boldsymbol{v}_1$ a $\boldsymbol{v}_2$ je vektor $\dfrac{1}{2}\boldsymbol{v}_1$.
#
# <font color=blue> a) Áno </font>
#
#
# b) Nie
#
#
# <ins> Vysvetlenie: </ins>
# Lineárna kombinácia vektorov $\boldsymbol{v}_1$ a $\boldsymbol{v}_2$ je  vyjadrenie nového vektora pomocou vynásobenia pôvodných vektorov konštantami a následným sčítaním takto vynásobených vektorov.
#
#
# $$
# p \cdot \boldsymbol{v}_1 + q \cdot \boldsymbol{v}_2 = \boldsymbol{v}_3 \quad (p, q \, \text{koeficienty})
# $$
#
# Otázka smeruje k tomu, či vieme nájsť také $p$ a $q$, aby $\boldsymbol{v}_3 = \frac{1}{2} \cdot \boldsymbol{v}_1$.
#
# Ilustračný príklad:
#
# Ak máme vektory $\boldsymbol{v}_1 = (6,10)$ a $\boldsymbol{v}_2 = (-8,13)$, potom:
#
# $$
# p \cdot \boldsymbol{v}_1 + q \cdot \boldsymbol{v}_2 = \boldsymbol{v}_3 = \frac{1}{2} \cdot \boldsymbol{v}_1
# $$
#
# Teda:
#
# $$
# p \cdot (6, 10) + q \cdot (-8, 13) = \left(\frac{1}{2} \cdot 6, \frac{1}{2} \cdot 10\right) = (3, 5)
# $$
#
# Dostaneme teda sústavu rovníc s dvomi neznámymi:
#
# $$
# \begin{aligned}
# 6p - 8q &= 3 \\
# 10p + 13q &= 5
# \end{aligned}
# $$
#
# Riešením tejto sústavy je $p = \frac{1}{2}$ a $q = 0$ (môžeš overiť). Ak sa to pozrieme, môžeme aj hneď vidieť, že $q=0$.
#
# Vyšli nám koeficienty $\frac{1}{2}$ a $0$, vďaka ktorým sme našli lineárnu kombináciu dvoch vektorov $\boldsymbol{v}_1$ a $\boldsymbol{v}_2$, ktorej výsledok je $\frac{1}{2} \cdot \boldsymbol{v}_1$.

# %% [markdown]
# ---
#
# #### 6. Skalárny súčin vektora samého so sebou môže byť záporný.
#
# a) Áno
# <font color=blue> b) Nie  </font>
#
# <ins> Vysvetlenie: </ins>
# Skalárny súčin vektoru so sebou samým je vždy nezáporný, pretože je to vlastne dĺžka (kvadrát) vektora. Skalárny súčin vektoru v sám so sebou sa zapisuje ako 𝒗⋅𝒗 alebo $∥\boldsymbol{v}∥^2$, kde $∥\boldsymbol{v}∥$ predstavuje dĺžku vektora $\boldsymbol{v}$.
#
# Keďže dĺžka vektora je vždy nezáporná, platí, že skalárny súčin vektoru so sebou samým je nezáporný. To znamená, že skalárny súčin vektoru sám so sebou nikdy nemôže byť záporný.
#
# Ilustračný príklad
# $\boldsymbol{v}=[1,2,3]$
# $∥\boldsymbol{v}∥^2=\boldsymbol{v}\cdot\boldsymbol{v}=x^2+y^2+z^2=1^2+2^2+3^2=1+4+9=14$
